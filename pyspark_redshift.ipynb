# %%
#import library
from pyspark.sql import SparkSession
from pyspark.sql.types import DoubleType
from pyspark.sql.functions import col

# %%
#we need redshift jdbc jar file
jar_path = 'redshift-jdbc42-2.0.0.4.jar,minimal-json-0.9.4.jar,spark-avro_2.11-3.0.0.jar,spark-redshift_2.11-2.0.4.jar'

# %%
#create spark session object
spark = SparkSession \
.builder \
.appName("integration_pyspark_redshift") \
.config("spark.jars", jar_path) \
.config("spark.driver.extraClassPath", jar_path) \
.getOrCreate()

# %%
#provide aws_credentials
spark._jsc.hadoopConfiguration().set("fs.s3.awsAccessKeyId", "AKIA5HR3523C76KHC5TA")
spark._jsc.hadoopConfiguration().set("fs.s3.awsSecretAccessKey", "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")

# %%
#create spark dataframe from csv file
AirlineDF = spark.read.option("header", "true").csv("airlines1.csv")

# %%
AirlineDF.show()
# Out:
# +---+----+-------+-----+----------+---------+----------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+------+--------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+----+--------------------+---------+-------------+--------------+-------+----------+-------+--------+---------------+--------+--------------------+----------+-------+---------+--------+------+----------+-------+--------+---------------+--------+------------------+----------+---------+----------------+--------+--------------+-----------------+-------+-------+--------+-------------+------------+------------+--------+-------------+-----------------+------------+-------------+---------------+------------------+--------------+--------------------+-----------+-----------+-----------+-------------+----------------+------------+--------------+
# ...

# %%
#create new dataframe and select some columns
AirlineDF1 = AirlineDF.select("Year", "Reporting_Airline")

# %%
AirlineDF1.show()
# Out:
# +----+-----------------+
# |Year|Reporting_Airline|
# +----+-----------------+
# |1998|               NW|
# |2009|               FL|
# |2013|               MQ|
# |2010|               DL|
# |2006|               US|
# |1995|               DL|
# |2006|               CO|
# |2019|               9E|
# |2008|               YV|
# |2018|               WN|
# |1991|               US|
# |2014|               WN|
# |1994|               AA|
# |2013|               OO|
# |2003|               UA|
# |1988|               PI|
# |2007|               NW|
# |2015|               AS|
# |2006|               UA|
# |2017|               WN|
# +----+-----------------+
# only showing top 20 rows

# %% [markdown]
# <h1> write dataframe into redshift </h1>

# %%
AirlineDF1.write \
.format("jdbc") \
.option("url","jdbc:redshift://redshift-cluster-1.cxzdfpwfqkof.us-east-1.redshift.amazonaws.com:5439/dev?user=testuser1&password=A1z2e3r4t5") \
.option("Tempdir", "s3://airlines555/airline/") \
.option("dbtable","airline") \
.mode("error") \
.save()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5612/1486946934.py in <module>
# ----> 1 AirlineDF1.write \
#       2 .format("jdbc") \
#       3 .option("url","jdbc:redshift://redshift-cluster-1.cxzdfpwfqkof.us-east-1.redshift.amazonaws.com:5439/dev?user=testuser1&password=A1z2e3r4t5") \
#       4 .option("Tempdir", "s3://airlines555/airline/") \
#       5 .option("dbtable","airline") \
#
# ~\anaconda3\lib\site-packages\pyspark\sql\readwriter.py in save(self, path, format, mode, partitionBy, **options)
#     964             self.format(format)
#     965         if path is None:
# --> 966             self._jwrite.save()
#     967         else:
#     968             self._jwrite.save(path)
#
# ~\anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# ...
